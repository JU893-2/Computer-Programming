# %%
x=2
y=2.2
z="hello"
print(x)
print(y)
print(z)
# Out:
# 2
# 2.2
# hello

# %% [markdown]
# # i created 3 variables. their names are x, y, and z. x is an integer, y is a float, z is a string
# # i used the print command to print them

# %%
jar1 = 5
jar2 = 10
hello="hello"
print(jar1+jar2+hello)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 jar1 = 5
#       2 jar2 = 10
#       3 hello="hello"
# ----> 4 print(jar1+jar2+hello)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # i cannot add integer and strings together in a line of code

# %%
jar1=5
jar2=10
print(jar2)

jar2=jar1
print(jar2)
# Out:
# 10
# 5

# %% [markdown]
# # whatever is on the left of the equals sign gets set to the value on the right of the equals sign

# %%
name="John"
age=8
print("My name is",name,"and I am",age,"years old!")
# Out:
# My name is John and I am 8 years old!

# %% [markdown]
# # when i am printing multiple things such as string literals and variables all at once, i seperate between them in the print statement with commas

# %%
my_name = "Jongwon Um"
print(my_name.upper())
print(my_name.lower())
print(my_name.upper(),my_name.lower())
# Out:
# JONGWON UM
# jongwon um
# JONGWON UM jongwon um

# %% [markdown]
# ### print is a function. I use it by itself and I put what I want to print in the parenthesis
# ### .upper () is a method. I use it on a string, meaning, I create a string, and then I call .upper() on the string that I want to convert to uppercase

# %%
my_life = "Adventures"
print(my_life.title())
# Out:
# Adventures

# %%
first_name = "Jongwon" 
last_name = "Um"
full_name = f"{first_name} {last_name}"

print(first_name, last_name)
print(full_name)
print(f"Hello, {full_name.title()}!")
print(f"Hello, {full_name.title()}!")
# Out:
# Jongwon Um
# Jongwon Um
# Hello, Jongwon Um!
# Hello, Jongwon Um!

# %% [markdown]
# ### I need curly braces { } and f string in order to be able to combine the two strings into one
#
# ### when building a string from other variables that are already strings, we can precede the quotes with an f and then inside the quotes, any time we are adding a preexisting variable, put the name of it in curly braces

# %%
print("grocery list:\n\tapples\n\tbananas \n\tmilk \ncelery \npeanut \nbutter \nbutter bread")
# Out:
# grocery list:
# 	apples
# 	bananas
# 	milk
# celery
# peanut
# butter
# butter bread

# %% [markdown]
# ### \n creates a new line under the same print function
# ### \t creates a tab

# %%
# there are three methods to clear whitespace: rstrip(), lstrip(), and strip()
name = "   Jongwon Um "
name_cleaned = name.strip().upper()
print(name)
print(name_cleaned)
# Out:
#    Jongwon Um
# JONGWON UM

# %% [markdown]
# #### there are three methods to clear whitespace: rstrip(), lstrip(), and strip()

# %%
name = input("enter your name")
print(name)
# Out:
# Bob

# %% [markdown]
# ### if i want input from the user, I can use the input function and in tne (), in quotes, I will write the message to the user. I will store the result in a variable, in this case my variable is name.

# %% [markdown]
# git add .
# git commit -m "message"
# git push
