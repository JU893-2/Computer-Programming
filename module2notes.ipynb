# %% [markdown]
# # module 2 notes: Lists

# %%
fav_words= ["apple", "phone", "running", "person", "shoe"]
print(fav_words)
print(fav_words[0])
#go to the last item in your list and print out 
print(fav_words[-1].upper())
print(fav_words[4].upper())

#print out a version of the 2nd item in your list that is capitalized like a book
print(fav_words[1].title())


#create and then print a string that says "one of my favorite words is: " and include one of your favorite words is: ""
#and incluude one of your favorite words


a="one of my favorite words is"
print(a, "apple")
print(a, fav_words[3])
my_sentence = f"One of my favorite words is {fav_words[3]} my list of words has {len(fav_words)} items"
print(my_sentence)

length=len(fav_words)
print(length)
print(len(fav_words))
print()
sentence_2 = f"I love {fav_words[0]} and I hate {fav_words[3]} my list of words has {len(fav_words)} items"
# Out:
# ['apple', 'phone', 'running', 'person', 'shoe']
# apple
# SHOE
# SHOE
# Phone
# one of my favorite words is apple
# one of my favorite words is person
# One of my favorite words is person my list of words has 5 items
# 5
# 5

# %% [markdown]
# ##### every item in a list has a location starting at 0. We can also start from the end with -1. The location is referred to as an index. So the first item in a list is at under 0. We can use the items in the list as is appropriate according to their type. If the items are strings, we can call string methods on them. If they are numbers, we can do math with them. The way we access a particular item in a list is name_of_list[index]. There is a len function that will tell us how long the list is.

# %%
print("Grocery list\nmilk\npopcorn\ncheese")
# Out:
# Grocery list
# milk
# popcorn
# cheese

# %%
# make a list with 3 items, the first is the month, the second is the date, and the third is the year

#make an f string that says "I was born in the year [insert year] on the day [insert day] of the month [insert day]"
# print the f string (use the values from your list)

bday= ["April", "6", "2010"]
print(bday)

bday_as_string = f"I was born in the year {bday[2]} on the day {bday[1]} of the month {bday[0]}"
print(bday_as_string)
# Out:
# ['April', '6', '2010']
# I was born in the year 2010 on the day 6 of the month April

# %%
# make a list of all of your siblings (at least 4)
# make an f string that explains which you like most, second most, etc. 

sibs=["Tom", "Bob", "Dan", "Chad"]
sibs_as_string= f"I like {sibs[3]} the most, {sibs[0]} comes after, {sibs[1]} is a close third pick and {sibs[2]} I hate the most."
sibs.append("Will")
print(sibs_as_string)

# w/o modifying any preexisting line of code, change the name of sibling 0
sibs[0]="Tommy"
print(sibs)
# Out:
# I like Chad the most, Tom comes after, Bob is a close third pick and Dan I hate the most.
# ['Tommy', 'Bob', 'Dan', 'Chad', 'Will']

# %%
# make a list of all of your most recent grades (at least 5)
# print your average
grades=[20,150, 75, 95, 97]
grades.insert(2, 160)
print((grades[0] + grades[1] + grades[2] + grades[3] + grades[4])/5)
# Out:
# 100.0

# %% [markdown]
# # i can change the value of an item in the list by resetting it. for example my_list [1] = "new value". I can also use methods on lists. Some methods I can use are .append() and .insert(). Append adds an item to the end of the list. insert adds an item somewhere in the list and shifts everything down to the right. Append takes on parameter which means I put one value in () and that value is the thing I'm adding to the list. Insert takes two parameters. The first is the location, the second is the item to insert at that location.

# %%
activities = ["gaming","studying", "eating","resting","running","sleeping"]
print(activities)

#activities.remove("sleeping")
activities.pop(5)
print(activities)

#remove requires value
#pop removes by index
# Out:
# ['gaming', 'studying', 'eating', 'resting', 'running', 'sleeping']
# ['gaming', 'studying', 'eating', 'resting', 'running']

# %% [markdown]
# ### pop requires me to know the index of the value i'm trying to remove whereas remove requires me to know the exact value

# %%
numbers = [3,5,8,10,11,28,42,77,101,108,2002]
# without modifying the code above 
print(numbers)
# change the 8 into 1
numbers[2] = 1

# insert a 50 at index 2
numbers.insert(2,50)

# remove the 108 by value 
numbers.remove(108)
# add 100 to the end
numbers.append(100)

#remove 2002 by negative index
numbers.pop(-2)
#remove 11 by postive index
numbers.pop(5)
print(numbers)

#use del to delete the 5
del(numbers[1])
print(numbers)
# Out:
# [3, 5, 8, 10, 11, 28, 42, 77, 101, 108, 2002]
# [3, 5, 50, 1, 10, 28, 42, 77, 101, 100]
# [3, 50, 1, 10, 28, 42, 77, 101, 100]

# %%
list = ["bucket","bottle","bag","chair","sofa"]
list.append("Hello")
print(list)
list.insert(3,1)
print(list)
#list.pop(1) we could also do this 
del(list[1])
list.remove("Hello")

x=list.pop()#(-1)
print(f"the last word in my list was {x}")
# Out:
# ['bucket', 'bottle', 'bag', 'chair', 'sofa', 'Hello']
# ['bucket', 'bottle', 'bag', 1, 'chair', 'sofa', 'Hello']
# the last word in my list was sofa

# %% [markdown]
# ### pop has three functionalities. 1. it can remove by index for example: list.pop(1) 2. it can store the value it deletes for a second so you can store it in a variable. for example y= list.pop(1) 3. it can make the executive decision to delete the last item if you don't give it any additional value. For example: list.pop()

# %%
elements= ["hydrogen","helium", "lithium", "beryllium","iron","aluminum", "boron", "rutherfordium", "carbon"]
print(elements)
elements.sort()
elements.reverse()
print(elements)

flowers = ["rose", "lily", "tulip", "sunflower", "lupine", "orchid", "lavender"]
print(sorted(flowers))
print(flowers)

print("rose" in flowers)
print("lapiz" in flowers)
# Out:
# ['hydrogen', 'helium', 'lithium', 'beryllium', 'iron', 'aluminum', 'boron', 'rutherfordium', 'carbon']
# ['rutherfordium', 'lithium', 'iron', 'hydrogen', 'helium', 'carbon', 'boron', 'beryllium', 'aluminum']
# ['lavender', 'lily', 'lupine', 'orchid', 'rose', 'sunflower', 'tulip']
# ['rose', 'lily', 'tulip', 'sunflower', 'lupine', 'orchid', 'lavender']
# True
# False

# %% [markdown]
# ### .sort() is a method that wll change the order of the list to be in alphabetical order
# ### .reverse() reverses the order of a list. Both of these fundamentally change the order of the list permanently
# ### on the other hand, sorted() is a function that can temporarily sort a list without permanently changing it

# %%
books = ["harry potter", "magic tree house", "beowulf", "red"]
books[0]=books[0].title()
books[1]=books[1].title()
books[2]=books[2].title()
books[3]=books[3].title()

print(books)
# Out:
# ['Harry Potter', 'Magic Tree House', 'Beowulf', 'Red']

# %%
teams = ["chargers", "rams", "lakers"]
print(teams)
print(teams[0])
print(teams[1])
for thing in teams: 
    print(thing)
    print("hello")
    print("jongwon")
print("loyola")
print("goodbye")

for thng in teams: 
    print(f"The {thing.title()} are my favorites!")
    print ("Go Team!")
print("\nPLay Ball")
# Out:
# ['chargers', 'rams', 'lakers']
# chargers
# rams
# chargers
# hello
# jongwon
# rams
# hello
# jongwon
# lakers
# hello
# jongwon
# loyola
# goodbye
# The Lakers are my favorites!
# Go Team!
# The Lakers are my favorites!
# Go Team!
# The Lakers are my favorites!
# Go Team!
#
# PLay Ball

# %%
songs = ["GOYD", "Lifes Like", "Filter", "All My Time", "Magnetic"]
for song in songs:
    print(f"I like {song}!")
print("I like these songs.")
# Out:
# I like GOYD!
# I like Lifes Like!
# I like Filter!
# I like All My Time!
# I like Magnetic!
# I like these songs.

# %%
numbers = list(range(1,100, 5))
list_of_names = ["a","b","c"]
print (numbers)

#using the range function, make a list from 0-250 by 7's

numbers = list(range(0,251, 7))
print (numbers)
# Out:
# [1, 6, 11, 16, 21, 26, 31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81, 86, 91, 96]
# [0, 7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98, 105, 112, 119, 126, 133, 140, 147, 154, 161, 168, 175, 182, 189, 196, 203, 210, 217, 224, 231, 238, 245]

# %% [markdown]
# #### when i use a for loop, the word after "for" is a moving variable. It will get set to a different item in the list every time the loop runs. That word, in my example song, does not exist outside of the loop. When I refer to things being inside and outside of the loop, i'm referring to whether or not something is indented below it or not. We learned two more functions. Range gives me numbers from the first parameter, up to but not including the second parameter. If i add a third, that will be the increment. The list function builds a list with whatever parameter i give it.
